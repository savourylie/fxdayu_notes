# %% [markdown]
# # 1. 价值选股
#
# 低PE/PB/PS/PCF

# %% [markdown]
# 本杰明·格雷厄姆的选股标准：(如果一家公司符合以下10条中的7条，可以考虑购买）
#
# 1.该公司每股盈利与股价之比（市盈率的倒数）是一般AAA公司债券收益率的 2 倍。
#
# 2.这家公司目前的市盈率应该是过去 5 年中最高市盈率的 2/5。
#
# 3.这家公司的股息收益率应该是 AAA 级公司债券收益率的 2/3。
#
# 4.这家公司的股价应该低于每股有形资产账面价值的 2/3。
#
# 5.这家公司的股价应该低于净流动资产或是净速动资产清算价值的 2/3。
#
# 6.这家公司的总负债应该低于有形资产价值。
#
# 7.这家公司的流动比率应该在 2 以上。
#
# 8.这家公司的总负债不超过净速动清算价值。
#
# 9.这家公司的获利在过去 10 年来增加了 1 倍。
#
# 10.这家公司的获利在过去 10 年中的 2 年减少不超过 5%。

# %% [markdown]
# ## Step1 获取沪深300成分股代号

# %%
from fxdayu_data import DataAPI
from datetime import datetime
import tushare as ts
import numpy as np
# from sklearn import preprocessing
import matplotlib.pyplot as plt
import pandas as pd

def coder(code):
    if code.startswith('6'):
        return code + '.XSHG'
    elif code.startswith('0') or code.startswith('3'):
        return code + '.XSHE'
    else:
        return code


name = ts.get_hs300s()
name_list = list(name.code)
codes = tuple(map(coder, name_list))
print(codes)
# Out:
# ('002736.XSHE', '600958.XSHG', '002500.XSHE', '601127.XSHG', '601225.XSHG', '002456.XSHE', '000983.XSHE', '000728.XSHE', '603993.XSHG', '002673.XSHE', '002230.XSHE', '601600.XSHG', '000750.XSHE', '601377.XSHG', '601688.XSHG', '601198.XSHG', '601118.XSHG', '600999.XSHG', '000686.XSHE', '000776.XSHE', '002475.XSHE', '000783.XSHE', '600489.XSHG', '600369.XSHG', '601555.XSHG', '000709.XSHE', '600309.XSHG', '600030.XSHG', '600188.XSHG', '601788.XSHG', '002008.XSHE', '002797.XSHE', '601211.XSHG', '600362.XSHG', '600737.XSHG', '000166.XSHE', '000712.XSHE', '600157.XSHG', '601099.XSHG', '600109.XSHG', '000630.XSHE', '000792.XSHE', '600068.XSHG', '600837.XSHG', '000338.XSHE', '601901.XSHG', '000060.XSHE', '000623.XSHE', '601866.XSHG', '002174.XSHE', '600688.XSHG', '601958.XSHG', '600582.XSHG', '600031.XSHG', '002241.XSHE', '600549.XSHG', '600061.XSHG', '000425.XSHE', '600150.XSHG', '600019.XSHG', '002236.XSHE', '002415.XSHE', '600585.XSHG', '600739.XSHG', '600170.XSHG', '000009.XSHE', '600498.XSHG', '600256.XSHG', '600875.XSHG', '600660.XSHG', '002081.XSHE', '600754.XSHG', '000069.XSHE', '002466.XSHE', '601727.XSHG', '601169.XSHG', '000568.XSHE', '000008.XSHE', '600036.XSHG', '000039.XSHE', '000793.XSHE', '600703.XSHG', '000839.XSHE', '000063.XSHE', '600089.XSHG', '300072.XSHE', '600583.XSHG', '600783.XSHG', '000778.XSHE', '600111.XSHG', '600649.XSHG', '600547.XSHG', '002027.XSHE', '001979.XSHE', '300059.XSHE', '600873.XSHG', '002131.XSHE', '600038.XSHG', '600115.XSHG', '000858.XSHE', '000800.XSHE', '601877.XSHG', '000413.XSHE', '600705.XSHG', '000725.XSHE', '600010.XSHG', '600271.XSHG', '600588.XSHG', '600816.XSHG', '601018.XSHG', '600704.XSHG', '000157.XSHE', '000938.XSHE', '000402.XSHE', '601333.XSHG', '002385.XSHE', '600406.XSHG', '000625.XSHE', '600820.XSHG', '600606.XSHG', '600839.XSHG', '000540.XSHE', '600570.XSHG', '600208.XSHG', '000826.XSHE', '600871.XSHG', '600153.XSHG', '002074.XSHE', '300058.XSHE', '002202.XSHE', '002304.XSHE', '601611.XSHG', '600893.XSHG', '600177.XSHG', '603000.XSHG', '600023.XSHG', '600015.XSHG', '601258.XSHG', '300015.XSHE', '002465.XSHE', '601718.XSHG', '002470.XSHE', '000559.XSHE', '002146.XSHE', '600016.XSHG', '601766.XSHG', '002299.XSHE', '600648.XSHG', '600373.XSHG', '600685.XSHG', '002714.XSHE', '600376.XSHG', '000768.XSHE', '600118.XSHG', '002152.XSHE', '300024.XSHE', '600252.XSHG', '300146.XSHE', '002594.XSHE', '300251.XSHE', '601216.XSHG', '600221.XSHG', '000671.XSHE', '000027.XSHE', '600827.XSHG', '600372.XSHG', '000415.XSHE', '300124.XSHE', '002183.XSHE', '601899.XSHG', '600340.XSHG', '601928.XSHG', '600060.XSHG', '600000.XSHG', '600037.XSHG', '600332.XSHG', '000917.XSHE', '601186.XSHG', '601009.XSHG', '600519.XSHG', '600718.XSHG', '000738.XSHE', '603885.XSHG', '601607.XSHG', '600535.XSHG', '300133.XSHE', '600008.XSHG', '000423.XSHE', '300070.XSHE', '000156.XSHE', '002195.XSHE', '601888.XSHG', '600637.XSHG', '601006.XSHG', '600085.XSHG', '600276.XSHG', '002450.XSHE', '000876.XSHE', '300144.XSHE', '600415.XSHG', '000963.XSHE', '601318.XSHG', '600804.XSHG', '600674.XSHG', '601857.XSHG', '600895.XSHG', '600352.XSHG', '600482.XSHG', '000895.XSHE', '601628.XSHG', '000718.XSHE', '000333.XSHE', '600021.XSHG', '601800.XSHG', '600297.XSHG', '601328.XSHG', '600867.XSHG', '601939.XSHG', '600029.XSHG', '002310.XSHE', '000538.XSHE', '300315.XSHE', '002065.XSHE', '002007.XSHE', '601166.XSHG', '601618.XSHG', '600196.XSHG', '600886.XSHG', '000001.XSHE', '600518.XSHG', '600074.XSHG', '600741.XSHG', '002424.XSHE', '002292.XSHE', '600446.XSHG', '601390.XSHG', '600690.XSHG', '600383.XSHG', '300027.XSHE', '300182.XSHE', '600887.XSHG', '601021.XSHG', '600663.XSHG', '601989.XSHG', '601988.XSHG', '601985.XSHG', '601933.XSHG', '601919.XSHG', '601872.XSHG', '601818.XSHG', '601608.XSHG', '601088.XSHG', '600959.XSHG', '600795.XSHG', '600666.XSHG', '600654.XSHG', '600485.XSHG', '600100.XSHG', '600050.XSHG', '300104.XSHE', '002739.XSHE', '002426.XSHE', '002252.XSHE', '002129.XSHE', '000977.XSHE', '000555.XSHE', '000503.X ...

# %% [markdown]
# ## Step2 获取Panel与几个的DataFrame

# %%
factor = DataAPI.factor('HS300', ('ROE'), start=datetime(2014, 1, 1), end=datetime(2017, 1, 1))
candle = DataAPI.candle('HS300', 'D', start=datetime(2014, 1, 1), end=datetime(2017, 1, 1))

# %%
prices = candle.minor_xs('close')

# %%
# Out:
#                      000001.XSHE  000002.XSHE  000008.XSHE  000009.XSHE  \
# 2014-01-02 15:00:00        12.23         7.99         9.00         9.40
# 2014-01-03 15:00:00        11.93         7.84         8.95         9.15
# 2014-01-06 15:00:00        11.67         7.48         8.51         9.07
# 2014-01-07 15:00:00        11.63         7.43         8.39         9.05
# 2014-01-08 15:00:00        11.76         7.42         8.23         8.89
#
#                      000027.XSHE  000039.XSHE  000060.XSHE  000061.XSHE  \
# 2014-01-02 15:00:00         5.47        15.48          NaN         8.31
# 2014-01-03 15:00:00         5.34        15.72          NaN         8.27
# 2014-01-06 15:00:00         5.22        15.20          NaN         7.94
# 2014-01-07 15:00:00         5.20        15.66          NaN         8.01
# 2014-01-08 15:00:00         5.26        15.59          NaN         8.00
#
#                      000063.XSHE  000069.XSHE     ...       601933.XSHG  \
# 2014-01-02 15:00:00        13.80         5.26     ...             14.06
# 2014-01-03 15:00:00        14.07         5.15     ...             14.26
# 2014-01-06 15:00:00        13.63         4.98     ...             13.71
# 2014-01-07 15:00:00        13.37         4.96     ...             13.76
# 2014-01-08 15:00:00        13.41         4.94     ...             14.19
#
#                      601939.XSHG  601958.XSHG  601985.XSHG  601988.XSHG  \
# 2014-01-02 15:00:00         4.11         7.13          NaN       2.6100
# 2014-01-03 15:00:00         4.07         7.05          NaN       2.5600
# 2014-01-06 15:00:00         4.08         6.70          NaN       2.5299
# 2014-01-07 15:00:00         4.01         6.74          NaN       2.5200
# 2014-01-08 15:00:00         3.98         6.59          NaN       2.5099
#
#                      601989.XSHG  601998.XSHG  603000.XSHG  603885.XSHG  \
# 2014-01-02 15:00:00         5.63         3.86        78.48          NaN
# 2014-01-03 15:00:00         5.53         3.80        77.23          NaN
# 2014-01-06 15:00:00         5.21         3.74        76.94          NaN
# 2014-01-07 15:00:00         5.16         3.73        78.90          NaN
# 2014-01-08 15:00:00         5.15         3.74        81.00          NaN
#
#                      603993.XSHG
# 2014-01-02 15:00:00       6.3600
# 2014-01-03 15:00:00       6.2600
# 2014-01-06 15:00:00       6.0199
# 2014-01-07 15:00:00       6.0199
# 2014-01-08 15:00:00       5.9300
#
# [5 rows x 300 columns]

# %%
roe = factor.minor_xs('ROE')

# %%
roe_factor = roe.stack()

# %%
import Alphalens

factor_data = alphalens.utils.get_clean_factor_and_forward_returns(roe_factor, prices, quantiles=3, periods=(1, 5, 10))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-2276196f1b73> in <module>()
# ----> 1 import Alphalens
#       2
#       3 factor_data = alphalens.utils.get_clean_factor_and_forward_returns(roe_factor, prices, quantiles=3, periods=(1, 5, 10))
#
# ImportError: No module named Alphalens

# %% [markdown]
# ## Step3 对数据进行标准化处理

# %%
def winsorize(df):
    q = df.quantile([0.025, 0.975])
    if isinstance(q, pd.Series) and len(q) == 2:
        df[df < q.iloc[0]] = q.iloc[0]
        df[df > q.iloc[1]] = q.iloc[1]
    return df

def standardize(df):
    df_std = df.std()
    df_mean = df.mean()
    return (df - df_mean) / df_std

S_PE = standardize(winsorize(PN.minor_xs('PE')))
S_PB = standardize(winsorize(PN.minor_xs('PB')))
S_PS = standardize(winsorize(PN.minor_xs('PS')))
S_PCF = standardize(winsorize(PN.minor_xs('PCF')))
fig = plt.figure(figsize=(15, 7))
plt.plot(S_PB)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-63c1bede1702> in <module>()
#      11     return (df - df_mean) / df_std
#      12
# ---> 13 S_PE = standardize(winsorize(PN.minor_xs('PE')))
#      14 S_PB = standardize(winsorize(PN.minor_xs('PB')))
#      15 S_PS = standardize(winsorize(PN.minor_xs('PS')))
#
# <ipython-input-5-63c1bede1702> in winsorize(df)
#       1 def winsorize(df):
# ----> 2     q = df.quantile([0.025, 0.975])
#       3     if isinstance(q, pd.Series) and len(q) == 2:
#       4         df[df < q.iloc[0]] = q.iloc[0]
#       5         df[df > q.iloc[1]] = q.iloc[1]
#
# /Users/calvinku/anaconda/envs/fxdayu/lib/python2.7/site-packages/pandas/core/frame.pyc in quantile(self, q, axis, numeric_only, interpolation)
#    5423                                      axis=1,
#    5424                                      interpolation=interpolation,
# -> 5425                                      transposed=is_transposed)
#    5426
#    5427         if result.ndim == 2:
#
# /Users/calvinku/anaconda/envs/fxdayu/lib/python2.7/site-packages/pandas/core/internals.pyc in quantile(self, **kwargs)
#    3198
#    3199     def quantile(self, **kwargs):
# -> 3200         return self.reduction('quantile', **kwargs)
#    3201
#    3202     def setitem(self, **kwargs):
#
# /Users/calvinku/anaconda/envs/fxdayu/lib/python2.7/site-packages/pandas/core/internals.pyc in reduction(self, f, axis, consolidate, transposed, **kwargs)
#    3168
#    3169         # single block
# -> 3170         values = _concat._concat_compat([b.values for b in blocks])
#    3171
#    3172         # compute the orderings of our original data
#
# /Users/calvinku/anaconda/envs/fxdayu/lib/python2.7/site-packages/pandas/core/dtypes/concat.pyc in _concat_compat(to_concat, axis)
#     164                 to_concat = [x.astype('object') for x in to_concat]
#     165
# --> 166     return np.concatenate(to_concat, axis=axis)
#     167
#     168
#
# ValueError: need at least one array to concatenate

# %% [markdown]
# ## Step4 输入因子算法，输出因子的Pipeline格式

# %%
S = -(S_PE+2*S_PB+2*S_PS+0.5*S_PCF)
factor = S.stack()

print(factor)
# Out:
# datetime
# 2013-01-04 15:00:00  000001.XSHE     0.811598
#                      000002.XSHE    -1.787618
#                      000008.XSHE    -7.294753
#                      000009.XSHE     4.239800
#                      000027.XSHE     3.517933
#                      000039.XSHE     3.708381
#                      000060.XSHE     1.728151
#                      000061.XSHE     4.028867
#                      000063.XSHE     7.975591
#                      000069.XSHE   -13.242184
#                      000100.XSHE     0.851304
#                      000156.XSHE     3.175610
#                      000157.XSHE    -5.271736
#                      000338.XSHE   -10.158154
#                      000402.XSHE    -3.113505
#                      000413.XSHE    -0.032468
#                      000415.XSHE    -1.489766
#                      000423.XSHE    -7.724833
#                      000425.XSHE     0.394259
#                      000503.XSHE     6.738091
#                      000538.XSHE    -0.977481
#                      000540.XSHE    -1.954622
#                      000555.XSHE     1.133842
#                      000559.XSHE     7.457215
#                      000568.XSHE    -4.258716
#                      000623.XSHE    -1.765191
#                      000625.XSHE     2.492571
#                      000627.XSHE     3.054007
#                      000630.XSHE    -4.673243
#                      000651.XSHE    -0.372701
#                                       ...
# 2017-06-13 15:00:00  601628.XSHG    -2.270291
#                      601633.XSHG     2.172434
#                      601668.XSHG    -7.014207
#                      601669.XSHG    -2.350053
#                      601688.XSHG     1.879615
#                      601718.XSHG    -1.299054
#                      601727.XSHG     1.354651
#                      601766.XSHG     0.670015
#                      601788.XSHG     1.697682
#                      601800.XSHG    -3.363697
#                      601818.XSHG     1.804367
#                      601857.XSHG     1.536293
#                      601866.XSHG    -4.123059
#                      601872.XSHG     1.707516
#                      601877.XSHG     6.613776
#                      601888.XSHG    -4.377033
#                      601899.XSHG     1.507140
#                      601901.XSHG     2.184190
#                      601919.XSHG     1.337975
#                      601928.XSHG     6.842442
#                      601933.XSHG    -4.748143
#                      601939.XSHG    -3.131819
#                      601958.XSHG     3.784603
#                      601985.XSHG     3.114931
#                      601988.XSHG     1.208658
#                      601989.XSHG    -0.125210
#                      601998.XSHG     0.843555
#                      603000.XSHG     0.559766
#                      603885.XSHG     5.626689
#                      603993.XSHG     1.716010
# dtype: float64

# %% [markdown]
# ## Step5 用Alphalens输出Quantile为5的股票列表

# %%
import alphalens

factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor, prices, quantiles=5)
cond = factor_data['factor_quantile'] == 5
save = factor_data[cond]
s = pd.Series(True, index=save.index)
s = s.unstack()
s[s != True] = False
# s.to_excel('C:/Users/small/Desktop/july_first/Value_Selection.xlsx')
print(s)
# Out:
# /Users/calvinku/anaconda/envs/fxdayu/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88e9bc2eef34> in <module>()
#       1 import alphalens
#       2
# ----> 3 factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor, prices, quantiles=5)
#       4 cond = factor_data['factor_quantile'] == 5
#       5 save = factor_data[cond]
#
# NameError: name 'factor' is not defined

# %% [markdown]
# ## Step6 显示Quantile收益与因子IC值

# %%
mean_return_by_q, std_err_by_q = alphalens.performance.mean_return_by_quantile(factor_data, by_date=True)
# print(mean_return_by_q).head()
# print(std_err_by_q).head()

alphalens.plotting.plot_cumulative_returns_by_quantile(mean_return_by_q, 1)
alphalens.plotting.plot_cumulative_returns_by_quantile(mean_return_by_q, 5)
alphalens.plotting.plot_cumulative_returns_by_quantile(mean_return_by_q, 10)
plt.show()
# Out:
# D:\ProgramData\Anaconda2\lib\site-packages\alphalens\plotting.py:767: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,min_periods=1,window=5).apply(args=<tuple>,func=<function>,kwargs=<dict>)
#   min_periods=1, args=(period,))
# D:\ProgramData\Anaconda2\lib\site-packages\alphalens\plotting.py:767: FutureWarning: pd.rolling_apply is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(center=False,min_periods=1,window=10).apply(args=<tuple>,func=<function>,kwargs=<dict>)
#   min_periods=1, args=(period,))

# %%
ic = alphalens.performance.factor_information_coefficient(factor_data)
# print ic
alphalens.plotting.plot_ic_hist(ic)
mean_monthly_ic = alphalens.performance.mean_information_coefficient(factor_data, by_time='M')
print mean_monthly_ic
alphalens.plotting.plot_monthly_ic_heatmap(mean_monthly_ic)
plt.show()
# Out:
#                   1         5         10
# date
# 2013-01-31  0.039407  0.043963  0.089886
# 2013-02-28  0.097427  0.231632  0.264346
# 2013-03-31  0.029124  0.003710  0.010848
# 2013-04-30  0.012614  0.029090  0.108843
# 2013-05-31  0.088444  0.164027  0.184383
# 2013-06-30  0.024834  0.034212  0.025115
# 2013-07-31  0.018179  0.022459  0.042642
# 2013-08-31  0.086225  0.165798  0.257991
# 2013-09-30  0.028551  0.088517  0.120227
# 2013-10-31  0.095307  0.184438  0.253471
# 2013-11-30  0.025996  0.063744  0.102805
# 2013-12-31  0.013999 -0.040776 -0.092962
# 2014-01-31 -0.031221 -0.033986  0.008671
# 2014-02-28  0.100258  0.200988  0.285051
# 2014-03-31  0.112162  0.257654  0.311149
# 2014-04-30  0.008232  0.046590  0.097888
# 2014-05-31  0.054601  0.069073  0.045246
# 2014-06-30  0.018130  0.052481  0.134638
# 2014-07-31  0.129588  0.256405  0.284347
# 2014-08-31  0.000658 -0.043592 -0.060853
# 2014-09-30  0.061759  0.106758  0.151765
# 2014-10-31  0.076966  0.118441  0.183938
# 2014-11-30  0.027222  0.053617  0.067092
# 2014-12-31 -0.013546  0.042159  0.065819
# 2015-01-31  0.158734  0.320557  0.355636
# 2015-02-28  0.066628  0.141079  0.251341
# 2015-03-31  0.070047  0.104377  0.073066
# 2015-04-30  0.082800  0.153900  0.247906
# 2015-05-31  0.080271  0.155620  0.224897
# 2015-06-30  0.138567  0.276014  0.357340
# 2015-07-31  0.117399  0.221275  0.236682
# 2015-08-31  0.073996  0.170915  0.196427
# 2015-09-30  0.054461  0.106033  0.100351
# 2015-10-31  0.064921  0.105935  0.190402
# 2015-11-30  0.097827  0.158275  0.178295
# 2015-12-31  0.098499  0.190638  0.249189
# 2016-01-31  0.078773  0.068030  0.045151
# 2016-02-29  0.034197  0.092779  0.193890
# 2016-03-31  0.075128  0.133892  0.165243
# 2016-04-30  0.056961  0.109670  0.103964
# 2016-05-31  0.059635  0.135955  0.178436
# 2016-06-30  0.077779  0.086867  0.115133
# 2016-07-31  0.062836  0.108465  0.102994
# 2016-08-31  0.062075  0.116180  0.183424
# 2016-09-30  0.046091  0.054167  0.076404
# 2016-10-31  0.030932 -0.000465 -0.049930
# 2016-11-30  0.009797  0.015078  0.018944
# 2016-12-31  0.025380  0.019135 -0.005932
# 2017-01-31  0.006570 -0.007062 -0.050214
# 2017-02-28  0.034817  0.077999  0.132899
# 2017-03-31 -0.022729 -0.105981 -0.163290
# 2017-04-30 -0.031857 -0.029633 -0.062319
# 2017-05-31 -0.041673 -0.088439 -0.129173
