# %% [markdown]
# ## 什么是Alpha101?
# *用数学公式找到Alpha机会*

# %% [markdown]
# ## 目录
#
# 1. Alpha101是什么？
# 2. Alpha101用到的算法有哪些？
# 3. Alpha001-010怎么写？
# 4. 用柱图展示因子绩效
# 5. 如何用TA_Lib设计新的Alpha因子？

# %% [markdown]
# ## Alpha101是什么？
# WorldQuant根据数据挖掘的方法发掘了101个alpha，据说里面 80% 的因子仍然还行之有效并运行在他们的投资策略中。Alpha101给出的公式，也就是计算机代码101年真实的定量交易Alpha。他们的平均持有期大约范围0.6 - 6.4天。平均两两这些Alpha的相关性较低,为15.9%。回报是与波动强相关，但对换手率没有明显的依赖性，直接确认较早的间接经验分析结果。我们从经验上进一步发现换手率对alpha相关性的解释能力很差。
#
# PDF下载：
#
# Python代码下载：## Alpha101主要元素有什么？
# ### 1. 因子组成元素
# - 价量因子（52/101）：
#     - HLOC
#     - ADV
#     - VWAP
#     - Volume
# - 价格波动因子（21/101）:
#     - HLOC
#     - Return
#     - STD()
# - 组合因子(8/101): 价量与价波因子组合
# - 市值因子（1/101）:
#     - Return
#     - Cap
# - 板块组合因子（19/101）: 板块分类结合价量与价波因子
#
# ### 2. 函数与运算符
# - 'x?y:z'是指x为True，返回y，否则返回z。
# - Rank是指横向的品种间排序。
# - ts_Rank是指纵向的时间序列排序。
#
# 详细参考原文PDF

# %% [markdown]
# ## Alpha101用到的算法有哪些？
# ### Step1 编制函数需要的算法

# %%
# 1. 编制函数需要的算法，
#coding=utf-8
import numpy as np
import pandas as pd
from scipy.stats import rankdata

# 计算alpha101时会使用的函数
# 移动求和
def ts_sum(df,window=10):
    return df.rolling(window).sum()

#移动平均
def ts_mean(df,window=10):
    return df.rolling(window).mean()

#移动标准差
def stddev(df,window=10):
    return df.rolling(window).std()

#移动相关系数
def correlation(x,y,window=10):
    return x.rolling(window).corr(y)

#移动协方差
def covariance(x,y,window=10):
    return x.rolling(window).cov(y)


def rolling_rank(na):
    return rankdata(na)[-1]

#移动排序
def ts_rank(df, window=10):
    return df.rolling(window).apply(rolling_rank)

def rolling_prod(na):
    return na.prod(na)

#移动乘积
def product(df,window=10):
    return df.rolling(window).apply(rolling_prod)

# 移动窗口最小值
def ts_min(df,window=10):
    return df.rolling(window).min()

# 移动窗口最大值
def ts_max(df,window=10):
    return df.rolling(window).max()

# 差值
def delta(df,period=1):
    return df.diff(period)

# 位移
def delay(df,period=1):
    return df.shift(period)

# 横向排序
def rank(df):
    return df.rank(axis=1, pct=True)

# 数值规模
def scale(df,k=1):
    return df.mul(k).div(np.abs(df).sum())

# 最大值的坐标
def ts_argmax(df,window=10):
    return df.rolling(window).apply(np.argmax)+1

# 最小值的坐标
def ts_argmin(df,window=10):
    return df.rolling(window).apply(np.argmin)+1

# 加权平均
def decay_linear(df,period=10):
    if df.isnull().values.any():
        df.fillna(method='ffill',inplace=True)
        df.fillna(method='bfill',inplace=True)
        df.fillna(value=0, inplace=True)
    return pd.DataFrame(
        {name: ta.WMA(item.values, period) for name, item in df.iteritems()},
        index=df.index
    )

# %%
# 2. 定义计算alpha值的类
class alphas(object):
    def __init__(self, pn_data):
        """
        :传入参数 pn_data: pandas.Panel
        """
        # 获取历史数据
        if pn_data.isnull().values.any():
            pn_data.fillna(method='ffill',inplace=True)
        self.open = pd.DataFrame(pn_data.minor_xs('open'), dtype=np.float64)
        self.high = pd.DataFrame(pn_data.minor_xs('high'), dtype=np.float64)
        self.low = pd.DataFrame(pn_data.minor_xs('low'), dtype=np.float64)
        self.close = pd.DataFrame(pn_data.minor_xs('close'), dtype=np.float64)
        self.volume = pd.DataFrame(pn_data.minor_xs('volume'), dtype=np.float64)
        self.returns = pd.DataFrame(self.close.pct_change())
        self.adv = ts_mean(self.volume, 10)
        self.vwap = ts_sum(self.close*self.volume, 10)/ts_sum(self.volume, 10)

# 3. 编制因子的函数
    
    #   alpha001:(rank(Ts_ArgMax(SignedPower(((returns < 0) ? stddev(returns, 20) : close), 2.), 5)) -0.5)
    def alpha001(self):
        inner = self.close
        inner[self.returns < 0] = stddev(self.returns, 20)
        alpha = rank(ts_argmax(inner ** 2, 5))
        return alpha
    
    #  alpha002:(-1 * correlation(rank(delta(log(volume), 2)), rank(((close - open) / open)), 6))
    def alpha002(self):
        alpha = -1 * correlation(rank(delta(np.log(self.volume), 2)), rank((self.close - self.open) / self.open), 6)
        return alpha.replace([-np.inf, np.inf], np.nan)

    # alpha003:(-1 * correlation(rank(open), rank(volume), 10))
    def alpha003(self):
        alpha = -1 * correlation(rank(self.open), rank(self.volume), 10)
        return alpha.replace([-np.inf, np.inf], np.nan)

    # alpha004: (-1 * Ts_Rank(rank(low), 9))
    def alpha004(self):
        alpha = -1 * ts_rank(rank(self.low), 9)
        return alpha
    
    # alpha005:(rank((open - (sum(vwap, 10) / 10))) * (-1 * abs(rank((close - vwap)))))
    def alpha005(self):
        alpha = (rank((self.open - (ts_sum(self.vwap, 10) / 10))) * (-1 * np.abs(rank((self.close - self.vwap)))))
        return alpha
    
    # alpha006: (-1 * correlation(open, volume, 10))
    def alpha006(self):
        alpha = -1 * correlation(self.open, self.volume, 10)
        return alpha
        
    # alpha007: ((adv20 < volume) ? ((-1 * ts_rank(abs(delta(close, 7)), 60)) * sign(delta(close, 7))) : (-1* 1))
    def alpha007(self):
        adv20 = ts_mean(self.volume, 20)
        alpha = -1 * ts_rank(abs(delta(self.close, 7)), 60) * np.sign(delta(self.close, 7))
        alpha[adv20 >= self.volume] = -1
        return alpha

    # alpha008: (-1 * rank(((sum(open, 5) * sum(returns, 5)) - delay((sum(open, 5) * sum(returns, 5)),10))))
    def alpha008(self):
        alpha = -1 * (rank(((ts_sum(self.open, 5) * ts_sum(self.returns, 5)) -
                          delay((ts_sum(self.open, 5) * ts_sum(self.returns, 5)), 10))))
        return alpha
    
    # alpha009:((0 < ts_min(delta(close, 1), 5)) ? delta(close, 1) : ((ts_max(delta(close, 1), 5) < 0) ?delta(close, 1) : (-1 * delta(close, 1))))
    def alpha009(self):
        delta_close = delta(self.close, 1)
        cond_1 = ts_min(delta_close, 5) > 0
        cond_2 = ts_max(delta_close, 5) < 0
        alpha = -1 * delta_close
        alpha[cond_1 | cond_2] = delta_close
        return alpha

    # alpha010: rank(((0 < ts_min(delta(close, 1), 4)) ? delta(close, 1) : ((ts_max(delta(close, 1), 4) < 0)? delta(close, 1) : (-1 * delta(close, 1)))))
    def alpha010(self):
        delta_close = delta(self.close, 1)
        cond_1 = ts_min(delta_close, 4) > 0
        cond_2 = ts_max(delta_close, 4) < 0
        alpha = -1 * delta_close
        alpha[cond_1 | cond_2] = delta_close
        return alpha

# %% [markdown]
# ### Step2 获取股票池

# %%
# 4. 传入股票池数据
if __name__ == '__main__':
    from fxdayu_data import DataAPI
    from datetime import datetime
    import tushare as ts
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    import alphalens
    
    #输入config的位置
    DataAPI.set_file('D:/PycharmProjects/Quant_Alpha/Data_Manager/Factor_Selection/config.py')

    #改名字的方法
    def coder(code):
        if code.startswith('6'):
            return code + '.XSHG'
        elif code.startswith('0') or code.startswith('3'):
            return code + '.XSHE'
        else:
            return code
    
    #获取沪深300的股票名
    name = ts.get_hs300s()
    name_list = list(name.code)
    codes = tuple(map(coder, name_list))
    print(codes)
# Out:
# ('002568.XSHE', '002008.XSHE', '000413.XSHE', '002456.XSHE', '002714.XSHE', '000768.XSHE', '300315.XSHE', '300146.XSHE', '002299.XSHE', '600028.XSHG', '600703.XSHG', '000338.XSHE', '601857.XSHG', '000008.XSHE', '600816.XSHG', '002081.XSHE', '000009.XSHE', '002594.XSHE', '002475.XSHE', '600893.XSHG', '002310.XSHE', '002153.XSHE', '000738.XSHE', '600252.XSHG', '000725.XSHE', '002146.XSHE', '600663.XSHG', '601877.XSHG', '300124.XSHE', '002465.XSHE', '600018.XSHG', '000839.XSHE', '000415.XSHE', '600115.XSHG', '600895.XSHG', '600170.XSHG', '601985.XSHG', '601928.XSHG', '601727.XSHG', '600021.XSHG', '601607.XSHG', '002230.XSHE', '600900.XSHG', '002195.XSHE', '600406.XSHG', '600118.XSHG', '000039.XSHE', '600061.XSHG', '002241.XSHE', '600741.XSHG', '600886.XSHG', '601669.XSHG', '601628.XSHG', '600031.XSHG', '600518.XSHG', '600547.XSHG', '601111.XSHG', '600688.XSHG', '002736.XSHE', '601899.XSHG', '000559.XSHE', '002074.XSHE', '600482.XSHG', '601633.XSHG', '600015.XSHG', '601618.XSHG', '601398.XSHG', '000063.XSHE', '600271.XSHG', '601198.XSHG', '000977.XSHE', '002450.XSHE', '600585.XSHG', '601989.XSHG', '601919.XSHG', '601872.XSHG', '601608.XSHG', '601328.XSHG', '601288.XSHG', '601088.XSHG', '600959.XSHG', '600871.XSHG', '600795.XSHG', '600674.XSHG', '600666.XSHG', '600654.XSHG', '600485.XSHG', '600415.XSHG', '600150.XSHG', '600104.XSHG', '600100.XSHG', '600050.XSHG', '300104.XSHE', '300085.XSHE', '002739.XSHE', '002426.XSHE', '002252.XSHE', '002131.XSHE', '002129.XSHE', '002049.XSHE', '000671.XSHE', '000503.XSHE', '000425.XSHE', '000100.XSHE', '000061.XSHE', '601211.XSHG', '600783.XSHG', '601788.XSHG', '002673.XSHE', '600000.XSHG', '600489.XSHG', '600685.XSHG', '601390.XSHG', '600029.XSHG', '600196.XSHG', '600008.XSHG', '002385.XSHE', '600009.XSHG', '600705.XSHG', '000166.XSHE', '300033.XSHE', '300182.XSHE', '601021.XSHG', '601818.XSHG', '600111.XSHG', '600376.XSHG', '601988.XSHG', '600837.XSHG', '600498.XSHG', '601866.XSHG', '600157.XSHG', '600958.XSHG', '600372.XSHG', '600089.XSHG', '000027.XSHE', '600074.XSHG', '600221.XSHG', '600867.XSHG', '300133.XSHE', '601258.XSHG', '002152.XSHE', '600023.XSHG', '601766.XSHG', '601336.XSHG', '601601.XSHG', '600038.XSHG', '000983.XSHE', '000157.XSHE', '600066.XSHG', '603885.XSHG', '600256.XSHG', '300059.XSHE', '601939.XSHG', '601099.XSHG', '600875.XSHG', '603000.XSHG', '600369.XSHG', '601958.XSHG', '600754.XSHG', '600309.XSHG', '000800.XSHE', '300002.XSHE', '600177.XSHG', '600820.XSHG', '000793.XSHE', '300027.XSHE', '000917.XSHE', '000001.XSHE', '600648.XSHG', '300070.XSHE', '000718.XSHE', '000709.XSHE', '600873.XSHG', '000630.XSHE', '601901.XSHG', '000333.XSHE', '600016.XSHG', '600637.XSHG', '600649.XSHG', '000776.XSHE', '000963.XSHE', '600804.XSHG', '601377.XSHG', '600839.XSHG', '002500.XSHE', '300251.XSHE', '000623.XSHE', '000778.XSHE', '600208.XSHG', '601333.XSHG', '300144.XSHE', '600010.XSHG', '600446.XSHG', '600297.XSHG', '000156.XSHE', '600588.XSHG', '600583.XSHG', '002466.XSHE', '600332.XSHG', '601998.XSHG', '002797.XSHE', '601216.XSHG', '601611.XSHG', '300024.XSHE', '002065.XSHE', '300058.XSHE', '000555.XSHE', '601166.XSHG', '000625.XSHE', '601018.XSHG', '600030.XSHG', '300168.XSHE', '000712.XSHE', '601169.XSHG', '000750.XSHE', '600085.XSHG', '600549.XSHG', '002183.XSHE', '600739.XSHG', '002304.XSHE', '601009.XSHG', '600827.XSHG', '002142.XSHE', '002470.XSHE', '600999.XSHG', '000728.XSHE', '300072.XSHE', '600737.XSHG', '002424.XSHE', '601127.XSHG', '601225.XSHG', '300017.XSHE', '000686.XSHE', '601688.XSHG', '601555.XSHG', '600718.XSHG', '601718.XSHG', '600535.XSHG', '300015.XSHE', '600704.XSHG', '000651.XSHE', '600037.XSHG', '600352.XSHG', '600060.XSHG', '601155.XSHG', '000876.XSHE', '000895.XSHE', '000826.XSHE', '000423.XSHE', '600606.XSHG', '601668.XSHG', '000792.XSHE', '601006.XSHG', '600276.XSHG', '000538.XSHE', '600519.XSHG', '600188.XSHG', '002024.XSHE', '000540.XSHE', '601118.XSHG', '601186.XSHG', '600887.XSHG', '600582.XSHG', '601600.XSHG', '002292.XSHE', '601888.XSHG', '000060.X ...

# %% [markdown]
# ### Step3 读取数据并计算IC值

# %%
    PN = DataAPI.factor(codes, ('open', 'high', 'low', 'close', 'volume'), start=datetime(2013, 1, 1))
    prices = PN.minor_xs('close')
    print PN
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 300 (items) x 1077 (major_axis) x 5 (minor_axis)
# Items axis: 000001.XSHE to 603993.XSHG
# Major_axis axis: 2013-01-04 15:00:00 to 2017-06-13 15:00:00
# Minor_axis axis: close to volume

# %%
    from collections import OrderedDict
    
    alpha = alphas(PN)
    factors = {'one': alpha.alpha001(),
               'two': alpha.alpha002(),
               'three': alpha.alpha003(),
               'four': alpha.alpha004(),
               'five': alpha.alpha005(),
               'six': alpha.alpha006(),
               'seven': alpha.alpha007(),
               'eight': alpha.alpha008(),
               'nine': alpha.alpha009(),
               'ten': alpha.alpha010()}


    def cal_monthly_ic(factor):
        factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor.stack(), prices, quantiles=5)
        return alphalens.performance.mean_information_coefficient(factor_data, by_time='M')

    monthly_ic = {key: cal_monthly_ic(value) for key, value in factors.items()}

    monthly_ic_mean = pd.DataFrame(
        map(lambda frame: frame.mean(), monthly_ic.values()),
        monthly_ic.keys()
    )
    print monthly_ic_mean
# Out:
#              1         5         10
# seven  0.027752  0.023779  0.013035
# ten   -0.002093  0.006620  0.008070
# nine   0.003646  0.010576  0.010947
# six    0.006309  0.015718  0.022268
# three  0.011407  0.025741  0.032815
# two    0.023380  0.016637  0.008115
# four   0.041261  0.045942  0.025938
# eight  0.035222  0.033412  0.021704
# five   0.032408  0.025092  0.004000
# one   -0.041200 -0.040805 -0.015505

# %%
    monthly_ic_std = pd.DataFrame(
        map(lambda frame: frame.std(), monthly_ic.values()),
        monthly_ic.keys()
    )
    print monthly_ic_std
# Out:
#              1         5         10
# seven  0.029685  0.027288  0.028126
# ten    0.029508  0.018764  0.017134
# nine   0.029523  0.018158  0.018170
# six    0.026876  0.047382  0.059567
# three  0.018956  0.033515  0.036883
# two    0.037097  0.042231  0.048794
# four   0.036224  0.053324  0.059885
# eight  0.046580  0.067485  0.063003
# five   0.050908  0.064015  0.076780
# one    0.074208  0.060520  0.064817

# %% [markdown]
# ### Step4 用柱图显示IC的均值与标准差

# %%
    import matplotlib.pyplot as plt
    import numpy as np
    import matplotlib.pyplot as plt

    fig, ax = plt.subplots()
    N=10
    ind = np.arange(N)  # the x locations for the groups
    width = 0.3       # the width of the bars
    # Example data
    ind_name = tuple(monthly_ic_mean.index)
    y_pos = np.arange(len(ind))
    one_mean = monthly_ic_mean.iloc[:,0]
    one_std = monthly_ic_std.iloc[:,0]
    five_mean = monthly_ic_mean.iloc[:,1]
    five_std = monthly_ic_std.iloc[:,1]
    ten_mean = monthly_ic_mean.iloc[:,2]
    ten_std = monthly_ic_std.iloc[:,2]

    ax.barh(ind - width, one_mean, align='edge',height=0.2, xerr=one_std,
            color='r', label='one_day')
    ax.barh(ind - 0.05, five_mean, align='edge',height=0.2,xerr=five_std,
            color='y', label='five_day')
    ax.barh(ind + width, ten_mean, align='center',height=0.2,xerr=ten_std,
            color='b', label='ten_day')

    ax.set_yticks(y_pos)
    ax.set_yticklabels(ind_name)
#     ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('mean_IC')
    ax.set_title('IC in Different Period')
    plt.legend()
    plt.show()

# %% [markdown]
# ## 如何用TA_Lib设计新的Alpha因子？
# 加入slope技术指标

# %%
import talib as ta
import numpy as np

def slope(df, period=10):
    return pd.DataFrame(
        {name: ta.LINEARREG_SLOPE(item.values, period) for name, item in df.iteritems()},
        index=df.index
        )

class alphas(object):
    def __init__(self, pn_data):
        self.close = pd.DataFrame(pn_data.minor_xs('close'), 
                                  dtype=np.float64)

# 自制因子
    def slope001(self):
        alpha = -1 * slope(self.close)
        return alpha

print alphas(PN).slope001().tail(5)
# Out:
#                      000001.XSHE  000002.XSHE  000008.XSHE  000009.XSHE  \
# datetime
# 2017-06-07 15:00:00     0.468032     0.394098    -0.825076    -0.508490
# 2017-06-08 15:00:00     0.150155    -0.528292    -0.391822    -0.295820
# 2017-06-09 15:00:00    -0.166025    -0.149693    -0.356104    -0.475409
# 2017-06-12 15:00:00     0.001076    -0.929336    -0.311639    -0.243290
# 2017-06-13 15:00:00    -0.438850    -1.714130    -0.274481    -0.028803
#
#                      000027.XSHE  000039.XSHE  000060.XSHE  000061.XSHE  \
# datetime
# 2017-06-07 15:00:00    -0.527817    -0.964975    -0.730131    -0.581137
# 2017-06-08 15:00:00    -0.494012    -0.508576    -0.559069    -0.925861
# 2017-06-09 15:00:00    -0.382459     0.025234    -0.365330    -0.172980
# 2017-06-12 15:00:00    -0.256944     0.354929    -0.308335     0.580023
# 2017-06-13 15:00:00    -0.138483    -0.467419    -0.289608     0.247463
#
#                      000063.XSHE  000069.XSHE     ...       601933.XSHG  \
# datetime                                          ...
# 2017-06-07 15:00:00    -0.682056    -0.150418     ...         -0.329169
# 2017-06-08 15:00:00    -1.398532    -0.572111     ...         -0.129520
# 2017-06-09 15:00:00    -0.849224    -0.428489     ...         -0.394047
# 2017-06-12 15:00:00    -1.372891    -0.764451     ...          0.180940
# 2017-06-13 15:00:00     0.586259     0.000161     ...          0.755829
#
#                      601939.XSHG  601958.XSHG  601985.XSHG  601988.XSHG  \
# datetime
# 2017-06-07 15:00:00     0.045057    -0.475734     0.342082     0.025351
# 2017-06-08 15:00:00    -0.171908     0.099668     0.162100    -0.106439
# 2017-06-09 15:00:00     0.021982     0.236086    -0.023458     0.206226
# 2017-06-12 15:00:00    -0.128668     0.282615    -0.211682     0.272712
# 2017-06-13 15:00:00    -0.287439     0.322012    -0.398876     0.096387
#
#                      601989.XSHG  601998.XSHG  603000.XSHG  603885.XSHG  \
# datetime
# 2017-06-07 15:00:00    -0.346623    -0.075819    -0.708276    -0.675892
# 2017-06-08 15:00:00    -0.011818    -0.363187     0.407481    -0.081584
# 2017-06-09 15:00:00    -0.003273    -0.252770     0.647606     0.645220
# 2017-06-12 15:00:00     0.000000    -0.144400     0.717213     1.174633
# 2017-06-13 15:00:00     0.000000     0.301515    -0.093011     0.599558
#
#                      603993.XSHG
# datetime
# 2017-06-07 15:00:00     0.020607
# 2017-06-08 15:00:00    -0.184985
# 2017-06-09 15:00:00    -0.395304
# 2017-06-12 15:00:00    -0.607805
# 2017-06-13 15:00:00    -0.551658
#
# [5 rows x 300 columns]

# %% [markdown]
# ## 读取三号因子选中的股票池

# %%
factor_003 = alpha.alpha003().stack()

factor_data = alphalens.utils.get_clean_factor_and_forward_returns(factor_003, prices, quantiles=5)

# print factor_data

cond = factor_data['factor_quantile'] == 5
Q5 = factor_data[cond]
stocks = pd.Series(True, index=Q5.index)
stocks = stocks.unstack()
stocks[stocks != True] = False
print(stocks)
stocks.to_excel('C:/Users/small/Desktop/july_first/alpha003_Selection.xlsx')
# Out:
# asset               000001.XSHE 000002.XSHE 000008.XSHE 000009.XSHE  \
# date
# 2013-01-17 15:00:00       False       False       False        True
# 2013-01-18 15:00:00       False       False       False        True
# 2013-01-21 15:00:00       False       False       False       False
# 2013-01-22 15:00:00       False       False       False       False
# 2013-01-23 15:00:00       False       False       False       False
# 2013-01-24 15:00:00       False       False       False        True
# 2013-01-25 15:00:00       False       False       False       False
# 2013-01-28 15:00:00       False       False       False        True
# 2013-01-29 15:00:00       False       False        True       False
# 2013-01-30 15:00:00        True       False        True       False
# 2013-01-31 15:00:00        True       False       False       False
# 2013-02-01 15:00:00        True       False       False       False
# 2013-02-04 15:00:00        True       False       False       False
# 2013-02-05 15:00:00        True       False       False       False
# 2013-02-06 15:00:00        True       False       False       False
# 2013-02-07 15:00:00        True       False       False       False
# 2013-02-08 15:00:00        True       False       False       False
# 2013-02-18 15:00:00       False       False       False       False
# 2013-02-19 15:00:00        True       False       False       False
# 2013-02-20 15:00:00        True       False       False       False
# 2013-02-21 15:00:00        True        True       False       False
# 2013-02-22 15:00:00        True        True       False       False
# 2013-02-25 15:00:00        True        True       False        True
# 2013-02-26 15:00:00        True        True       False        True
# 2013-02-27 15:00:00        True        True       False        True
# 2013-02-28 15:00:00       False       False        True       False
# 2013-03-01 15:00:00       False       False        True       False
# 2013-03-04 15:00:00       False       False        True       False
# 2013-03-05 15:00:00       False       False       False       False
# 2013-03-06 15:00:00       False       False       False       False
# ...                         ...         ...         ...         ...
# 2017-04-14 15:00:00       False        True       False       False
# 2017-04-17 15:00:00       False       False       False       False
# 2017-04-18 15:00:00       False       False       False       False
# 2017-04-19 15:00:00       False       False       False       False
# 2017-04-20 15:00:00       False       False       False       False
# 2017-04-21 15:00:00       False       False        True       False
# 2017-04-24 15:00:00       False        True        True       False
# 2017-04-25 15:00:00       False        True        True       False
# 2017-04-26 15:00:00       False       False        True       False
# 2017-04-27 15:00:00        True       False        True       False
# 2017-04-28 15:00:00        True        True        True       False
# 2017-05-02 15:00:00       False        True        True       False
# 2017-05-03 15:00:00        True        True        True       False
# 2017-05-04 15:00:00       False       False        True       False
# 2017-05-05 15:00:00       False       False        True       False
# 2017-05-08 15:00:00       False       False        True       False
# 2017-05-09 15:00:00       False       False       False       False
# 2017-05-10 15:00:00        True       False       False        True
# 2017-05-11 15:00:00       False       False       False       False
# 2017-05-12 15:00:00       False       False       False       False
# 2017-05-15 15:00:00       False       False       False       False
# 2017-05-16 15:00:00       False       False       False       False
# 2017-05-17 15:00:00       False       False       False       False
# 2017-05-18 15:00:00       False       False       False       False
# 2017-05-19 15:00:00       False       False       False       False
# 2017-05-22 15:00:00       False       False       False       False
# 2017-05-23 15:00:00       False       False       False       False
# 2017-05-24 15:00:00       False       False       False       False
# 2017-05-25 15:00:00       False       False        True       False
# 2017-05-26 15:00:00       False       False        True       False
#
# asset               000027.XSHE 000039.XSHE 000060.XSHE 000061.XSHE  \
# date
# 2013-01-17 15:00:00        True       False       False        True
# 2013-01-18 15:00:00        True       False       False        True
# 2013-01-21 15:00:00        True       False       False        True
# 2013-01-22 15:00:00        True       False       False        True
# 2013-01-23 15:00:00        True       False       False        True
# 2013-01-24 15:00:00       False       False       False       False
# 2013-01-25 15:00:00       False       False       False       False
# 2013-01-28 15:00:00       False       False       False       False
# 2013-01-29 15:00:00       False       False       False       False
# 2013-01-30 15:00:00       False       False        True       False
# 2013-01-31 15:00:00       False       False        True       False
# 2013-02-01 15:00:00       False       False       False       False
# 2013-02-04 15:00:00       False       False       False       False
# 2013-02-05 15:00:00        True       False       False       False
# 2013-02-06 15:00:00        True       False       False       False
# 2013-02-07 15:00:00       False       False       False       False
# 2013-02-08 15:00:00       False       False       False       False
# 2013-02-18 15:00:00       False       False       False       False
# 2013-02-19 15:00:00       False       False       False       False
# 2013-02-20 15:00:00        True       False       False       False
# 2013-02-21 15:00:00       False       False       False       False
# 2013-02-22 15:00:00       False       False       False       False
# 2013-02-25 15:00:00       False       False       False        True
# 2013-02-26 15:00:00        True       False       False        True
# 2013-02-27 15:00:00        True       False       False        True
# 2013-02-28 15:00:00        True       False       False       False
# 2013-03-01 15:00:00        True       False       False       False
# 2013-03-04 15:00:00       False       False        True       False
# 2013-03-05 15:00:00       False       False       False       False
# 2013-03-06 15:00:00       False       False       False       False
# ...                         ...         ...         ...         ...
# 2017-04-14 15:00:00       False       False       False       False
# 2017-04-17 15:00:00       False       False       False       False
# 2017-04-18 15:00:00       False       False       False       False
# 2017-04-19 15:00:00       False       False       False       False
# 2017-04-20 15:00:00       False       False       False       False
# 2017-04-21 15:00:00       False       False       False       False
# 2017-04-24 15:00:00       False       False       False       False
# 2017-04-25 15:00:00       False       False       False       False
# 2017-04-26 15:00:00       False       False       False       False
# 2017-04-27 15:00:00        True       False       False        True
# 2017-04-28 15:00:00        True       False       False        True
# 2017-05-02 15:00:00       False       False       False        True
# 2017-05-03 15:00:00       False       False       False        True
# 2017-05-04 15:00:00       False        True       False        True
# 2017-05-05 15:00:00       False        True       False       False
# 2017-05-08 15:00:00       False       False        True       False
# 2017-05-09 15:00:00       False       False       False       False
# 2017-05-10 15:00:00       False       False       False       False
# 2017-05-11 15:00:00       False       False       False       False
# 2017-05-12 15:00:00       False       False       False       False
# 2017-05-15 15:00:00       False       False       False       False
# 2017-05-16 15:00:00       False       False       False       False
# 2017-05-17 15:00:00       False       False       False       False
# 2017-05-18 15:00:00       False       False       False       False
# 2017-05-19 15:00:00        True       False       False       False
# 2017-05-22 15:00:00       False       False       False       False
# 2017-05-23 15:00:00       False       False       False       False
# 2017-05-24 15:00:00       False       False       False       False
# 2017-05-25 15:00:00       False       False       False       False
# 2017-05-26 15:00:00       False       False       False       False
#
# asset               000063.XSHE 000069.XSHE     ...     601933.XSHG  \
# date                                            ...
# 2013-01-17 15:00:00        True       False     ...           False
# 2013-01-18 15:00:00        True       False     ...           False
# 2013-01-21 15:00:00        True       False     ...           False
# 2013-01-22 15:00:00        True       False     ...           False
# 2013-01-23 15:00:00        True       False     ...           False
# 2013-01-24 15:00:00        True       False     ...           False
# 2013-01-25 15:00:00        True        True     ...           False
# 2013-01-28 15:00:00        True        True     ...           False
# 2013-01-29 15:00:00        True       False     ...           False
# 2013-01-30 15:00:00        True       False     ...            True
# 2013-01-31 15:00:00        True       False     ...            True
# 2013-02-01 15:00:00        True       False     ...            True
# 2013-02-04 15:00:00        True       False     ...            True
# 2013-02-05 15:00:00       False       False     ...            True
# 2013-02-06 15:00:00       False       False     ...            True
# 2013-02-07 15:00:00       False       False     ...            True
# 2013-02-08 15:00:00       False       False     ...            True
# 2013-02-18 15:00:00       False       False     ...            True
# 2013-02-19 15:00:00        True       False     ...            True
# 2013-02-20 15:00:00       False       False     ...            True
# 2013-02-21 15:00:00       False        True     ...            True
# 2013-02-22 15:00:00       False        True     ...            True
# 2013-02-25 15:00:00       False        True     ...           False
# 2013-02-26 15:00:00       False       False     ...           False
# 2013-02-27 15:00:00       False       False     ...           False
# 2013-02-28 15:00:00        True       False     ...           False
# 2013-03-01 15:00:00        True       False     ...           False
# 2013-03-04 15:00:00       False        True     ...           False
# 2013-03-05 15:00:00       False        True     ...           False
# 2013-03-06 15:00:00       False        True     ...           False
# ...                         ...         ...     ...             ...
# 2017-04-14 15:00:00       False       False     ...           False
# 2017-04-17 15:00:00       False       False     ...           False
# 2017-04-18 15:00:00       False       False     ...           False
# 2017-04-19 15:00:00       False       False     ...           False
# 2017-04-20 15:00:00       False       False     ...           False
# 2017-04-21 15:00:00       False       False     ...           False
# 2017-04-24 15:00:00       False       False     ...           False
# 2017-04-25 15:00:00       False       False     ...           False
# 2017-04-26 15:00:00       False       False     ...           False
# 2017-04-27 15:00:00       False       False     ...           False
# 2017-04-28 15:00:00       False       False     ...           False
# 2017-05-02 15:00:00       False        True     ...            True
# 2017-05-03 15:00:00       False       False     ...           False
# 2017-05-04 15:00:00       False       False     ...            True
# 2017-05-05 15:00:00       False       False     ...           False
# 2017-05-08 15:00:00       False       False     ...           False
# 2017-05-09 15:00:00        True       False     ...           False
# 2017-05-10 15:00:00       False       False     ...           False
# 2017-05-11 15:00:00       False       False     ...           False
# 2017-05-12 15:00:00       False       False     ...           False
# 2017-05-15 15:00:00       False       False     ...           False
# 2017-05-16 15:00:00       False       False     ...           False
# 2017-05-17 15:00:00       False       False     ...           False
# 2017-05-18 15:00:00       False       False     ...           False
# 2017-05-19 15:00:00       False       False     ...           False
# 2017-05-22 15:00:00       False       False     ...            True
# 2017-05-23 15:00:00       False       False     ...           False
# 2017-05-24 15:00:00       False       False     ...           False
# 2017-05-25 15:00:00       False       False     ...           False
# 2017-05-26 15:00:00       False       False     ...           False
#
# asset               601939.XSHG 601958.XSHG 601985.XSHG 601988.XSHG  \
# date
# 2013-01-17 15:00:00       False       False       False       False
# 2013-01-18 15:00:00       False       False       False       False
# 2013-01-21 15:00:00       False       False       False       False
# 2013-01-22 15:00:00       False       False       False        True
# 2013-01-23 15:00:00       False       False       False        True
# 2013-01-24 15:00:00       False       False       False        True
# 2013-01-25 15:00:00       False       False       False        True
# 2013-01-28 15:00:00       False       False       False        True
# 2013-01-29 15:00:00       False       False       False        True
# 2013-01-30 15:00:00       False       False       False       False
# 2013-01-31 15:00:00       False       False       False       False
# 2013-02-01 15:00:00       False       False       False       False
# 2013-02-04 15:00:00       False       False       False       False
# 2013-02-05 15:00:00        True       False       False       False
# 2013-02-06 15:00:00        True       False       False       False
# 2013-02-07 15:00:00        True       False       False       False
# 2013-02-08 15:00:00       False       False       False       False
# 2013-02-18 15:00:00       False       False       False       False
# 2013-02-19 15:00:00       False       False       False       False
# 2013-02-20 15:00:00       False       False       False       False
# 2013-02-21 15:00:00       False       False       False       False
# 2013-02-22 15:00:00       False       False       False       False
# 2013-02-25 15:00:00       False       False       False       False
# 2013-02-26 15:00:00       False       False       False       False
# 2013-02-27 15:00:00       False       False       False       False
# 2013-02-28 15:00:00       False       False       False       False
# 2013-03-01 15:00:00       False       False       False       False
# 2013-03-04 15:00:00       False       False       False       False
# 2013-03-05 15:00:00       False       False       False       False
# 2013-03-06 15:00:00       False       False       False       False
# ...                         ...         ...         ...         ...
# 2017-04-14 15:00:00       False       False       False       False
# 2017-04-17 15:00:00       False       False       False       False
# 2017-04-18 15:00:00       False        True       False       False
# 2017-04-19 15:00:00       False        True       False       False
# 2017-04-20 15:00:00       False       False        True       False
# 2017-04-21 15:00:00       False       False       False       False
# 2017-04-24 15:00:00       False       False       False       False
# 2017-04-25 15:00:00       False       False       False       False
# 2017-04-26 15:00:00       False       False       False       False
# 2017-04-27 15:00:00       False       False       False       False
# 2017-04-28 15:00:00       False       False       False       False
# 2017-05-02 15:00:00       False       False       False       False
# 2017-05-03 15:00:00       False       False       False       False
# 2017-05-04 15:00:00       False       False       False       False
# 2017-05-05 15:00:00       False       False       False       False
# 2017-05-08 15:00:00       False       False       False       False
# 2017-05-09 15:00:00       False       False       False       False
# 2017-05-10 15:00:00       False       False       False       False
# 2017-05-11 15:00:00       False       False       False       False
# 2017-05-12 15:00:00       False       False       False       False
# 2017-05-15 15:00:00       False       False       False       False
# 2017-05-16 15:00:00       False       False       False       False
# 2017-05-17 15:00:00       False       False       False       False
# 2017-05-18 15:00:00       False       False       False       False
# 2017-05-19 15:00:00       False       False       False       False
# 2017-05-22 15:00:00       False       False       False       False
# 2017-05-23 15:00:00       False       False       False       False
# 2017-05-24 15:00:00       False       False       False       False
# 2017-05-25 15:00:00       False        True        True       False
# 2017-05-26 15:00:00       False        True        True       False
#
# asset               601989.XSHG 601998.XSHG 603000.XSHG 603885.XSHG  \
# date
# 2013-01-17 15:00:00       False       False       False       False
# 2013-01-18 15:00:00       False       False       False       False
# 2013-01-21 15:00:00       False       False       False       False
# 2013-01-22 15:00:00       False       False       False       False
# 2013-01-23 15:00:00       False       False       False       False
# 2013-01-24 15:00:00       False       False       False       False
# 2013-01-25 15:00:00       False       False       False       False
# 2013-01-28 15:00:00       False       False       False       False
# 2013-01-29 15:00:00       False       False       False       False
# 2013-01-30 15:00:00       False       False       False       False
# 2013-01-31 15:00:00       False        True       False       False
# 2013-02-01 15:00:00       False        True       False       False
# 2013-02-04 15:00:00       False        True       False       False
# 2013-02-05 15:00:00       False        True       False       False
# 2013-02-06 15:00:00       False       False       False       False
# 2013-02-07 15:00:00       False       False       False       False
# 2013-02-08 15:00:00       False       False       False       False
# 2013-02-18 15:00:00       False       False       False       False
# 2013-02-19 15:00:00       False       False       False       False
# 2013-02-20 15:00:00       False       False       False       False
# 2013-02-21 15:00:00       False       False       False       False
# 2013-02-22 15:00:00       False       False       False       False
# 2013-02-25 15:00:00       False       False       False       False
# 2013-02-26 15:00:00       False       False       False       False
# 2013-02-27 15:00:00       False       False       False       False
# 2013-02-28 15:00:00       False       False       False       False
# 2013-03-01 15:00:00       False        True       False       False
# 2013-03-04 15:00:00       False       False       False       False
# 2013-03-05 15:00:00       False       False       False       False
# 2013-03-06 15:00:00       False       False       False       False
# ...                         ...         ...         ...         ...
# 2017-04-14 15:00:00       False       False       False       False
# 2017-04-17 15:00:00       False       False       False       False
# 2017-04-18 15:00:00       False        True       False        True
# 2017-04-19 15:00:00       False        True       False        True
# 2017-04-20 15:00:00       False        True       False        True
# 2017-04-21 15:00:00       False        True       False        True
# 2017-04-24 15:00:00       False        True       False        True
# 2017-04-25 15:00:00       False        True       False        True
# 2017-04-26 15:00:00        True        True       False        True
# 2017-04-27 15:00:00        True        True       False        True
# 2017-04-28 15:00:00       False       False       False        True
# 2017-05-02 15:00:00       False       False        True        True
# 2017-05-03 15:00:00       False       False       False        True
# 2017-05-04 15:00:00       False       False       False        True
# 2017-05-05 15:00:00       False       False       False        True
# 2017-05-08 15:00:00       False       False       False       False
# 2017-05-09 15:00:00       False       False       False       False
# 2017-05-10 15:00:00       False       False       False       False
# 2017-05-11 15:00:00       False       False       False       False
# 2017-05-12 15:00:00       False       False       False       False
# 2017-05-15 15:00:00       False       False       False       False
# 2017-05-16 15:00:00       False       False       False       False
# 2017-05-17 15:00:00       False       False       False       False
# 2017-05-18 15:00:00       False       False       False       False
# 2017-05-19 15:00:00       False       False       False       False
# 2017-05-22 15:00:00       False       False       False       False
# 2017-05-23 15:00:00       False       False       False        True
# 2017-05-24 15:00:00       False       False       False       False
# 2017-05-25 15:00:00       False       False       False        True
# 2017-05-26 15:00:00       False       False       False       False
#
# asset               603993.XSHG
# date
# 2013-01-17 15:00:00       False
# 2013-01-18 15:00:00       False
# 2013-01-21 15:00:00       False
# 2013-01-22 15:00:00       False
# 2013-01-23 15:00:00       False
# 2013-01-24 15:00:00       False
# 2013-01-25 15:00:00       False
# 2013-01-28 15:00:00       False
# 2013-01-29 15:00:00       False
# 2013-01-30 15:00:00       False
# 2013-01-31 15:00:00       False
# 2013-02-01 15:00:00       False
# 2013-02-04 15:00:00       False
# 2013-02-05 15:00:00        True
# 2013-02-06 15:00:00        True
# 2013-02-07 15:00:00        True
# 2013-02-08 15:00:00        True
# 2013-02-18 15:00:00        True
# 2013-02-19 15:00:00       False
# 2013-02-20 15:00:00       False
# 2013-02-21 15:00:00       False
# 2013-02-22 15:00:00       False
# 2013-02-25 15:00:00       False
# 2013-02-26 15:00:00       False
# 2013-02-27 15:00:00       False
# 2013-02-28 15:00:00       False
# 2013-03-01 15:00:00       False
# 2013-03-04 15:00:00       False
# 2013-03-05 15:00:00       False
# 2013-03-06 15:00:00       False
# ...                         ...
# 2017-04-14 15:00:00       False
# 2017-04-17 15:00:00       False
# 2017-04-18 15:00:00       False
# 2017-04-19 15:00:00       False
# 2017-04-20 15:00:00       False
# 2017-04-21 15:00:00       False
# 2017-04-24 15:00:00       False
# 2017-04-25 15:00:00        True
# 2017-04-26 15:00:00       False
# 2017-04-27 15:00:00       False
# 2017-04-28 15:00:00       False
# 2017-05-02 15:00:00       False
# 2017-05-03 15:00:00       False
# 2017-05-04 15:00:00       False
# 2017-05-05 15:00:00       False
# 2017-05-08 15:00:00       False
# 2017-05-09 15:00:00       False
# 2017-05-10 15:00:00       False
# 2017-05-11 15:00:00       False
# 2017-05-12 15:00:00       False
# 2017-05-15 15:00:00       False
# 2017-05-16 15:00:00       False
# 2017-05-17 15:00:00       False
# 2017-05-18 15:00:00       False
# 2017-05-19 15:00:00       False
# 2017-05-22 15:00:00       False
# 2017-05-23 15:00:00       False
# 2017-05-24 15:00:00       False
# 2017-05-25 15:00:00       False
# 2017-05-26 15:00:00       False
#
# [1058 rows x 299 columns]

# %% [markdown]
# ## 作业
# 下载Alpha101.pdf研究，并设计有效的Alpha因子，柱形图展示绩效，最后输出股票池Excel。
